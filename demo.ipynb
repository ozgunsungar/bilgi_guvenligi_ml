# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\osungar\\Desktop\\yuksekLisans\\Courses\\bilgiGuvenligiML\\Projects'

# %%
df = pd.read_csv('C:\\Users\\osungar\\Desktop\\yuksekLisans\\Courses\\bilgiGuvenligiML\\Projects\\data\\Spam.csv')

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# 1             0.00            0.94  ...         0.00        0.132
# 2             0.64            0.25  ...         0.01        0.143
# 3             0.31            0.63  ...         0.00        0.137
# 4             0.31            0.63  ...         0.00        0.135
#
#    char_freq_[  char_freq_!  char_freq_$  char_freq_hash  \
# 0          0.0        0.778        0.000           0.000
# 1          0.0        0.372        0.180           0.048
# 2          0.0        0.276        0.184           0.010
# 3          0.0        0.137        0.000           0.000
# 4          0.0        0.135        0.000           0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       3.756                          61
# 1                       5.114                         101
# 2                       9.821                         485
# 3                       3.537                          40
# 4                       3.537                          40
#
#    capital_run_length_total  spam
# 0                       278     1
# 1                      1028     1
# 2                      2259     1
# 3                       191     1
# 4                       191     1
#
# [5 rows x 58 columns]

# %%
df.shape
# Out:
# (4601, 58)

# %%
df[df['spam'] == 0 ].tail()
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 4596            0.31                0.0           0.62           0.0
# 4597            0.00                0.0           0.00           0.0
# 4598            0.30                0.0           0.30           0.0
# 4599            0.96                0.0           0.00           0.0
# 4600            0.00                0.0           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 4596           0.00            0.31               0.0                 0.0
# 4597           0.00            0.00               0.0                 0.0
# 4598           0.00            0.00               0.0                 0.0
# 4599           0.32            0.00               0.0                 0.0
# 4600           0.00            0.00               0.0                 0.0
#
#       word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 4596              0.0             0.0  ...        0.000        0.232
# 4597              0.0             0.0  ...        0.000        0.000
# 4598              0.0             0.0  ...        0.102        0.718
# 4599              0.0             0.0  ...        0.000        0.057
# 4600              0.0             0.0  ...        0.000        0.000
#
#       char_freq_[  char_freq_!  char_freq_$  char_freq_hash  \
# 4596          0.0        0.000          0.0             0.0
# 4597          0.0        0.353          0.0             0.0
# 4598          0.0        0.000          0.0             0.0
# 4599          0.0        0.000          0.0             0.0
# 4600          0.0        0.125          0.0             0.0
#
#       capital_run_length_average  capital_run_length_longest  \
# 4596                       1.142                           3
# 4597                       1.555                           4
# 4598                       1.404                           6
# 4599                       1.147                           5
# 4600                       1.250                           5
#
#       capital_run_length_total  spam
# 4596                        88     0
# 4597                        14     0
# 4598                       118     0
# 4599                        78     0
# 4600                        40     0
#
# [5 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
#  13  word_freq_report            4601 non-null   float64
#  14  word_freq_addresses         4601 non-null   float64
#  15  word_freq_free              4601 non-null   float64
#  16  word_freq_business          4601 non-null   float64
#  17  word_freq_email             4601 non-null   float64
#  18  word_freq_you               4601 non-null   float64
#  19  word_freq_credit            4601 non-null   float64
#  20  word_freq_your              4601 non-null   float64
#  21  word_freq_font              4601 non-null   float64
#  22  word_freq_000               4601 non-null   float64
#  23  word_freq_money             4601 non-null   float64
#  24  word_freq_hp                4601 non-null   float64
#  25  word_freq_hpl               4601 non-null   float64
#  26  word_freq_george            4601 non-null   float64
#  27  word_freq_650               4601 non-null   float64
#  28  word_freq_lab               4601 non-null   float64
#  29  word_freq_labs              4601 non-null   float64
#  30  word_freq_telnet            4601 non-null   float64
#  31  word_freq_857               4601 non-null   float64
#  32  word_freq_data              4601 non-null   float64
#  33  word_freq_415               4601 non-null   float64
#  34  word_freq_85                4601 non-null   float64
#  35  word_freq_technology        4601 non-null   float64
#  36  word_freq_1999              4601 non-null   float64
#  37  word_freq_parts             4601 non-null   float64
#  38  word_freq_pm                4601 non-null   float64
#  39  word_freq_direct            4601 non-null   float64
#  40  word_freq_cs                4601 non-null   float64
#  41  word_freq_meeting           4601 non-null   float64
#  42  word_freq_original          4601 non-null   float64
#  43  word_freq_project           4601 non-null   float64
#  44  word_freq_re                4601 non-null   float64
#  45  word_freq_edu               4601 non-null   float64
#  46  word_freq_table             4601 non-null   float64
#  47  word_freq_conference        4601 non-null   float64
#  48  char_freq_;                 4601 non-null   float64
#  49  char_freq_(                 4601 non-null   float64
#  50  char_freq_[                 4601 non-null   float64
#  51  char_freq_!                 4601 non-null   float64
#  52  char_freq_$                 4601 non-null   float64
#  53  char_freq_hash              4601 non-null   float64
#  54  capital_run_length_average  4601 non-null   float64
#  55  capital_run_length_longest  4601 non-null   int64
#  56  capital_run_length_total    4601 non-null   int64
#  57  spam                        4601 non-null   int64
# dtypes: float64(55), int64(3)
# memory usage: 2.0 MB

# %%
df.nunique().sort_values(ascending=False)
# Out:
# capital_run_length_average    2161
# char_freq_!                    964
# capital_run_length_total       919
# char_freq_(                    641
# word_freq_you                  575
# char_freq_$                    504
# word_freq_your                 401
# word_freq_hp                   395
# word_freq_will                 316
# char_freq_hash                 316
# char_freq_;                    313
# word_freq_hpl                  281
# capital_run_length_longest     271
# word_freq_our                  255
# word_freq_free                 253
# word_freq_mail                 245
# word_freq_george               240
# word_freq_re                   230
# word_freq_email                229
# word_freq_edu                  227
# char_freq_[                    225
# word_freq_all                  214
# word_freq_650                  200
# word_freq_business             197
# word_freq_1999                 188
# word_freq_meeting              186
# word_freq_data                 184
# word_freq_labs                 179
# word_freq_85                   177
# word_freq_remove               173
# word_freq_address              171
# word_freq_internet             170
# word_freq_000                  164
# word_freq_pm                   163
# word_freq_project              160
# word_freq_technology           159
# word_freq_people               158
# word_freq_lab                  156
# word_freq_credit               148
# word_freq_order                144
# word_freq_money                143
# word_freq_make                 142
# word_freq_over                 141
# word_freq_original             136
# word_freq_report               133
# word_freq_telnet               128
# word_freq_direct               125
# word_freq_addresses            118
# word_freq_receive              113
# word_freq_415                  110
# word_freq_cs                   108
# word_freq_conference           106
# word_freq_857                  106
# word_freq_font                  99
# word_freq_parts                 53
# word_freq_3d                    43
# word_freq_table                 38
# spam                             2
# dtype: int64

# %%
df.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4601.000000        4601.000000    4601.000000   4601.000000
# mean         0.104553           0.213015       0.280656      0.065425
# std          0.305358           1.290575       0.504143      1.395151
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4601.000000     4601.000000       4601.000000         4601.000000
# mean        0.312223        0.095901          0.114208            0.105295
# std         0.672513        0.273824          0.391441            0.401071
# min         0.000000        0.000000          0.000000            0.000000
# 25%         0.000000        0.000000          0.000000            0.000000
# 50%         0.000000        0.000000          0.000000            0.000000
# 75%         0.380000        0.000000          0.000000            0.000000
# max        10.000000        5.880000          7.270000           11.110000
#
#        word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# count      4601.000000     4601.000000  ...  4601.000000  4601.000000
# mean          0.090067        0.239413  ...     0.038575     0.139030
# std           0.278616        0.644755  ...     0.243471     0.270355
# min           0.000000        0.000000  ...     0.000000     0.000000
# 25%           0.000000        0.000000  ...     0.000000     0.000000
# 50%           0.000000        0.000000  ...     0.000000     0.065000
# 75%           0.000000        0.160000  ...     0.000000     0.188000
# max           5.260000       18.180000  ...     4.385000     9.752000
#
#        char_freq_[  char_freq_!  char_freq_$  char_freq_hash  \
# count  4601.000000  4601.000000  4601.000000     4601.000000
# mean      0.016976     0.269071     0.075811        0.044238
# std       0.109394     0.815672     0.245882        0.429342
# min       0.000000     0.000000     0.000000        0.000000
# 25%       0.000000     0.000000     0.000000        0.000000
# 50%       0.000000     0.000000     0.000000        0.000000
# 75%       0.000000     0.315000     0.052000        0.000000
# max       4.081000    32.478000     6.003000       19.829000
#
#        capital_run_length_average  capital_run_length_longest  \
# count                 4601.000000                 4601.000000
# mean                     5.191515                   52.172789
# std                     31.729449                  194.891310
# min                      1.000000                    1.000000
# 25%                      1.588000                    6.000000
# 50%                      2.276000                   15.000000
# 75%                      3.706000                   43.000000
# max                   1102.500000                 9989.000000
#
#        capital_run_length_total         spam
# count               4601.000000  4601.000000
# mean                 283.289285     0.394045
# std                  606.347851     0.488698
# min                    1.000000     0.000000
# 25%                   35.000000     0.000000
# 50%                   95.000000     0.000000
# 75%                  266.000000     1.000000
# max                15841.000000     1.000000
#
# [8 rows x 58 columns]

# %%
target = 'spam'
labels = ['Ham','Spam']
features = [i for i in df.columns.values if i not in [target]]

# %%
df_pie= df['spam'].value_counts()

# %%
print('\033[1mTarget Variable Distribution'.center(55))
df_pie.plot.pie(y='spam',figsize=(5,5), autopct='%1.1f%%')
# Out:
#             Target Variable Distribution
# <Axes: ylabel='count'>

# %% [markdown]
# # Data Preprocessing

# %%
df_clean = df.copy()
duplicate_rows = df_clean[df_clean.duplicated()]
duplicated_counts = duplicate_rows.shape[0]

if duplicated_counts > 0 :
    #we have duplicated rows
    df_clean.drop_duplicates(inplace=True)
    print('number of duplicates dropped --> {}'.format(duplicated_counts))
else : 
    print("there are no duplicated rows to get deleted")
# Out:
# number of duplicates dropped --> 391

# %%
from imblearn.over_sampling import SMOTE

#Fixing the imbalance using SMOTE Technique
df_smote = df_clean.copy()
print("Class distribution before SMOTE")
print(df_clean['spam'].value_counts())

columns = df_clean.columns
X = df_clean.iloc[:,:-1]
y = df_clean.iloc[:,-1]

smote=SMOTE()
X,y = smote.fit_resample(X,y)
df_smote = pd.DataFrame(X,columns=columns)
df_smote['spam']=y

print('\nClass distribution after applying SMOTE Technique:',)
print(y.value_counts())
# Out:
# Class distribution before SMOTE
# spam
# 0    2531
# 1    1679
# Name: count, dtype: int64
#
# Class distribution after applying SMOTE Technique:
# spam
# 1    2531
# 0    2531
# Name: count, dtype: int64

# %% [markdown]
# # Data Manipulation

# %%
df_smote.columns
# Out:
# Index(['word_freq_make', 'word_freq_address', 'word_freq_all', 'word_freq_3d',
#        'word_freq_our', 'word_freq_over', 'word_freq_remove',
#        'word_freq_internet', 'word_freq_order', 'word_freq_mail',
#        'word_freq_receive', 'word_freq_will', 'word_freq_people',
#        'word_freq_report', 'word_freq_addresses', 'word_freq_free',
#        'word_freq_business', 'word_freq_email', 'word_freq_you',
#        'word_freq_credit', 'word_freq_your', 'word_freq_font', 'word_freq_000',
#        'word_freq_money', 'word_freq_hp', 'word_freq_hpl', 'word_freq_george',
#        'word_freq_650', 'word_freq_lab', 'word_freq_labs', 'word_freq_telnet',
#        'word_freq_857', 'word_freq_data', 'word_freq_415', 'word_freq_85',
#        'word_freq_technology', 'word_freq_1999', 'word_freq_parts',
#        'word_freq_pm', 'word_freq_direct', 'word_freq_cs', 'word_freq_meeting',
#        'word_freq_original', 'word_freq_project', 'word_freq_re',
#        'word_freq_edu', 'word_freq_table', 'word_freq_conference',
#        'char_freq_;', 'char_freq_(', 'char_freq_[', 'char_freq_!',
#        'char_freq_$', 'char_freq_hash', 'capital_run_length_average',
#        'capital_run_length_longest', 'capital_run_length_total', 'spam'],
#       dtype='object')

# %%
df_manipulated = df_smote.copy()
df_manipulated.columns=[i.replace('[','_') for i in df_manipulated.columns]

X = df_manipulated.iloc[:,:-1]
y = df_manipulated.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, 
                                                    test_size=0.2, random_state=0)

print('Original set  ---> ',X.shape,y.shape,
      '\nTraining set  ---> ',X_train.shape,y_train.shape,
      '\nTesting set   ---> ', X_test.shape,'', y_test.shape)
# Out:
# Original set  --->  (5062, 57) (5062,)
# Training set  --->  (4049, 57) (4049,)
# Testing set   --->  (1013, 57)  (1013,)

# %%
# Feature Scaling (Standardization)

from sklearn.preprocessing import StandardScaler
std = StandardScaler()

print('Standardardization on Training set'.center(100))
X_train_std = std.fit_transform(X_train)
X_train_std = pd.DataFrame(X_train_std, columns=X.columns)
display(X_train_std.describe())

print('\nStandardardization on Testing set'.center(100))
X_test_std = std.transform(X_test)
X_test_std = pd.DataFrame(X_test_std, columns=X.columns)
display(X_test_std.describe())
# Out:
#                                  Standardardization on Training set
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count    4.049000e+03       4.049000e+03   4.049000e+03  4.049000e+03
# mean    -3.334234e-17      -5.615551e-17   1.754860e-17 -3.334234e-17
# std      1.000124e+00       1.000124e+00   1.000124e+00  1.000124e+00
# min     -3.843585e-01      -3.095301e-01  -6.225024e-01 -5.086847e-02
# 25%     -3.843585e-01      -3.095301e-01  -6.225024e-01 -5.086847e-02
# 50%     -3.843585e-01      -3.095301e-01  -6.225024e-01 -5.086847e-02
# 75%     -1.480154e-01      -3.095301e-01   3.901943e-01 -5.086847e-02
# max      1.494418e+01       2.506049e+01   9.504465e+00  3.072588e+01
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count   4.049000e+03    4.049000e+03      4.049000e+03        4.049000e+03
# mean   -2.193575e-18   -2.281318e-17     -4.474893e-17        3.334234e-17
# std     1.000124e+00    1.000124e+00      1.000124e+00        1.000124e+00
# min    -5.142565e-01   -3.843905e-01     -3.478258e-01       -2.892813e-01
# 25%    -5.142565e-01   -3.843905e-01     -3.478258e-01       -2.892813e-01
# 50%    -5.142565e-01   -3.843905e-01     -3.478258e-01       -2.892813e-01
# 75%     1.656033e-01   -2.121728e-01     -2.863159e-01       -2.892813e-01
# max     1.390020e+01    1.986841e+01      1.762451e+01        2.645290e+01
#
#        word_freq_order  word_freq_mail  ...  word_freq_conference  \
# count     4.049000e+03    4.049000e+03  ...          4.049000e+03
# mean     -2.720033e-17    1.052916e-17  ...          9.213014e-18
# std       1.000124e+00    1.000124e+00  ...          1.000124e+00
# min      -3.628323e-01   -4.055143e-01  ...         -1.076203e-01
# 25%      -3.628323e-01   -4.055143e-01  ...         -1.076203e-01
# 50%      -3.628323e-01   -4.055143e-01  ...         -1.076203e-01
# 75%      -3.628323e-01    5.502415e-02  ...         -1.076203e-01
# max       1.687003e+01    2.761960e+01  ...          3.400858e+01
#
#         char_freq_;   char_freq_(   char_freq__   char_freq_!   char_freq_$  \
# count  4.049000e+03  4.049000e+03  4.049000e+03  4.049000e+03  4.049000e+03
# mean   2.676161e-17 -4.913607e-17 -3.597463e-17  7.458154e-18 -3.948435e-18
# std    1.000124e+00  1.000124e+00  1.000124e+00  1.000124e+00  1.000124e+00
# min   -1.580782e-01 -4.919034e-01 -1.887876e-01 -3.785775e-01 -3.480734e-01
# 25%   -1.580782e-01 -4.919034e-01 -1.887876e-01 -3.785775e-01 -3.480734e-01
# 50%   -1.580782e-01 -2.301286e-01 -1.887876e-01 -2.818595e-01 -3.480734e-01
# 75%   -1.580782e-01  1.503174e-01 -1.887876e-01  8.944866e-02  3.659039e-02
# max    1.901613e+01  3.354580e+01  3.218028e+01  3.572725e+01  2.083667e+01
#
#        char_freq_hash  capital_run_length_average  capital_run_length_longest  \
# count    4.049000e+03                4.049000e+03                4.049000e+03
# mean     2.720033e-17                3.904563e-17               -8.774299e-18
# std      1.000124e+00                1.000124e+00                1.000124e+00
# min     -1.200333e-01               -1.489319e-01               -2.673827e-01
# 25%     -1.200333e-01               -1.262296e-01               -2.369193e-01
# 50%     -1.200333e-01               -1.013868e-01               -1.934000e-01
# 75%     -1.200333e-01               -4.936607e-02               -4.978649e-02
# max      5.468101e+01                3.557478e+01                4.319964e+01
#
#        capital_run_length_total
# count              4.049000e+03
# mean              -2.193575e-17
# std                1.000124e+00
# min               -4.875922e-01
# 25%               -4.218721e-01
# 50%               -3.158236e-01
# 75%               -2.008280e-02
# max                2.317167e+01
#
# [8 rows x 57 columns]
#
# Standardardization on Testing set
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     1013.000000        1013.000000    1013.000000   1013.000000
# mean         0.029708           0.076630       0.015788     -0.013576
# std          1.054171           1.590039       1.019935      0.781071
# min         -0.384359          -0.309530      -0.622502     -0.050868
# 25%         -0.384359          -0.309530      -0.622502     -0.050868
# 50%         -0.384359          -0.309530      -0.622502     -0.050868
# 75%         -0.114252          -0.239694       0.370338     -0.050868
# max          8.968074          37.745502       6.724513     22.751972
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    1013.000000     1013.000000       1013.000000         1013.000000
# mean       -0.008986       -0.014528         -0.008098            0.007259
# std         0.862780        0.845815          0.921005            0.952284
# min        -0.514257       -0.384391         -0.347826           -0.289281
# 25%        -0.514257       -0.384391         -0.347826           -0.289281
# 50%        -0.514257       -0.384391         -0.347826           -0.289281
# 75%         0.235295       -0.108842         -0.347826           -0.289281
# max         8.494781        6.848753          7.365200           14.225331
#
#        word_freq_order  word_freq_mail  ...  word_freq_conference  \
# count      1013.000000     1013.000000  ...           1013.000000
# mean         -0.043071        0.021902  ...             -0.040371
# std           0.832174        0.940848  ...              0.570209
# min          -0.362832       -0.405514  ...             -0.107620
# 25%          -0.362832       -0.405514  ...             -0.107620
# 50%          -0.362832       -0.405514  ...             -0.107620
# 75%          -0.362832        0.060493  ...             -0.107620
# max           4.617006        7.702962  ...             11.253073
#
#        char_freq_;  char_freq_(  char_freq__  char_freq_!  char_freq_$  \
# count  1013.000000  1013.000000  1013.000000  1013.000000  1013.000000
# mean     -0.007375    -0.044861    -0.013398    -0.064067    -0.046458
# std       1.084945     0.640341     1.580445     0.560861     0.667447
# min      -0.158078    -0.491903    -0.188788    -0.378578    -0.348073
# 25%      -0.158078    -0.491903    -0.188788    -0.378578    -0.348073
# 50%      -0.158078    -0.233619    -0.188788    -0.284083    -0.348073
# 75%      -0.158078     0.139846    -0.188788     0.048316     0.028316
# max      19.095163     6.251415    47.379867     7.756370     6.844081
#
#        char_freq_hash  capital_run_length_average  capital_run_length_longest  \
# count     1013.000000                 1013.000000                 1013.000000
# mean         0.070986                    0.022889                   -0.020779
# std          1.528879                    1.132386                    0.607222
# min         -0.120033                   -0.148932                   -0.267383
# 25%         -0.120033                   -0.126230                   -0.236919
# 50%         -0.120033                   -0.101750                   -0.202104
# 75%         -0.120033                   -0.054305                   -0.067194
# max         36.164345                   21.450698                    5.529381
#
#        capital_run_length_total
# count               1013.000000
# mean                  -0.035403
# std                    0.852049
# min                   -0.487592
# 25%                   -0.423366
# 50%                   -0.324785
# 75%                   -0.036513
# max                   13.088105
#
# [8 rows x 57 columns]

# %%
X_train_std = std.fit_transform(X_train)
X_train_std
# Out:
# array([[ 1.03369988, -0.30953008,  0.21148316, ...,  1.55156869,
#          1.87811621,  1.90521958],
#        [-0.38435851, -0.30953008, -0.62250236, ..., -0.08656544,
#         -0.03237879, -0.31881087],
#        [ 1.4192531 , -0.30953008,  0.07895227, ...,  0.04720585,
#          0.15040205,  0.03966281],
#        ...,
#        [ 0.72983022,  1.92900124,  0.70790311, ...,  0.02944339,
#          2.01302588,  0.79245753],
#        [-0.38435851, -0.30953008, -0.62250236, ..., -0.14893194,
#         -0.26738273, -0.48012402],
#        [-0.38435851, -0.30953008, -0.62250236, ..., -0.13544028,
#         -0.24562311, -0.4383021 ]])

# %% [markdown]
# # Feature Selection/Extraction

# %%
df[features].corr()
# Out:
#                             word_freq_make  word_freq_address  word_freq_all  \
# word_freq_make                    1.000000          -0.016759       0.065627
# word_freq_address                -0.016759           1.000000      -0.033526
# word_freq_all                     0.065627          -0.033526       1.000000
# word_freq_3d                      0.013273          -0.006923      -0.020246
# word_freq_our                     0.023119          -0.023760       0.077734
# word_freq_over                    0.059674          -0.024840       0.087564
# word_freq_remove                  0.007669           0.003918       0.036677
# word_freq_internet               -0.003950          -0.016280       0.012003
# word_freq_order                   0.106263          -0.003826       0.093786
# word_freq_mail                    0.041198           0.032962       0.032075
# word_freq_receive                 0.188459          -0.006864       0.048254
# word_freq_will                    0.105801          -0.040398       0.083210
# word_freq_people                  0.066438          -0.018858       0.047593
# word_freq_report                  0.036780          -0.009206       0.008552
# word_freq_addresses               0.028439           0.005330       0.122113
# word_freq_free                    0.059386          -0.009117       0.063906
# word_freq_business                0.081928          -0.018370       0.036262
# word_freq_email                   0.053324           0.033500       0.121923
# word_freq_you                     0.128243          -0.055476       0.139329
# word_freq_credit                  0.021295          -0.015806       0.031111
# word_freq_your                    0.197049          -0.018191       0.156651
# word_freq_font                   -0.024349          -0.008850      -0.035681
# word_freq_000                     0.134072          -0.020502       0.123671
# word_freq_money                   0.188155           0.001984       0.041145
# word_freq_hp                     -0.072504          -0.043483      -0.087924
# word_freq_hpl                    -0.061686          -0.038211      -0.062459
# word_freq_george                 -0.066424          -0.030307      -0.108886
# word_freq_650                    -0.048680          -0.029221      -0.050648
# word_freq_lab                    -0.041251          -0.021940      -0.057726
# word_freq_labs                   -0.052799          -0.027508      -0.032547
# word_freq_telnet                 -0.039066          -0.018097      -0.038927
# word_freq_857                    -0.032058          -0.003326      -0.061870
# word_freq_data                   -0.041014          -0.024903      -0.054759
# word_freq_415                    -0.027690          -0.004303      -0.061706
# word_freq_85                     -0.044954          -0.024058      -0.048335
# word_freq_technology             -0.054673          -0.028198      -0.046504
# word_freq_1999                   -0.057312          -0.024013      -0.067015
# word_freq_parts                  -0.007960          -0.008922       0.032407
# word_freq_pm                     -0.011134          -0.019124      -0.014809
# word_freq_direct                 -0.036095          -0.014821      -0.047066
# word_freq_cs                     -0.009703          -0.015420      -0.030956
# word_freq_meeting                -0.026070          -0.025177      -0.005811
# word_freq_original               -0.024292          -0.002370      -0.044325
# word_freq_project                -0.022116          -0.019739      -0.053464
# word_freq_re                     -0.037105          -0.016418      -0.050664
# word_freq_edu                    -0.034056          -0.023858      -0.056655
# word_freq_table                  -0.000953          -0.009818       0.029339
# word_freq_conference             -0.017755          -0.015747      -0.026344
# char_freq_;                      -0.026505          -0.007282      -0.033213
# char_freq_(                      -0.021196          -0.049837      -0.016495
# char_freq_[                      -0.033301          -0.018527      -0.033120
# char_freq_!                       0.058292          -0.014461       0.108140
# char_freq_$                       0.117419          -0.009605       0.087618
# char_freq_hash                   -0.008844           0.001946      -0.003336
# capital_run_length_average        0.044491           0.002083       0.097398
# capital_run_length_longest        0.061382           0.000271       0.107463
# capital_run_length_total          0.089165          -0.022680       0.070114
#
#                             word_freq_3d  word_freq_our  word_freq_over  \
# word_freq_make                  0.013273       0.023119        0.059674
# word_freq_address              -0.006923      -0.023760       -0.024840
# word_freq_all                  -0.020246       0.077734        0.087564
# word_freq_3d                    1.000000       0.003238       -0.010014
# word_freq_our                   0.003238       1.000000        0.054054
# word_freq_over                 -0.010014       0.054054        1.000000
# word_freq_remove                0.019784       0.147336        0.061163
# word_freq_internet              0.010268       0.029598        0.079561
# word_freq_order                -0.002454       0.020823        0.117438
# word_freq_mail                 -0.004947       0.034495        0.013897
# word_freq_receive              -0.012976       0.068382        0.053900
# word_freq_will                 -0.019221       0.066788        0.009264
# word_freq_people               -0.013199       0.031126        0.077631
# word_freq_report                0.012008       0.003445        0.009673
# word_freq_addresses             0.002707       0.056177        0.173066
# word_freq_free                  0.007432       0.083024        0.019865
# word_freq_business              0.003470       0.143443        0.064137
# word_freq_email                 0.019391       0.062344        0.078350
# word_freq_you                  -0.010834       0.098510        0.095505
# word_freq_credit               -0.005381       0.031526        0.058979
# word_freq_your                  0.008176       0.136605        0.106833
# word_freq_font                  0.028102      -0.020207        0.007956
# word_freq_000                   0.011368       0.070037        0.211455
# word_freq_money                 0.035360       0.000039        0.059329
# word_freq_hp                   -0.015181      -0.072502       -0.084402
# word_freq_hpl                  -0.013708      -0.075456       -0.087271
# word_freq_george               -0.010684      -0.088011       -0.069051
# word_freq_650                  -0.010368      -0.061501       -0.066223
# word_freq_lab                  -0.007798       0.032048       -0.048673
# word_freq_labs                 -0.010476      -0.052066       -0.048127
# word_freq_telnet               -0.007529      -0.042535       -0.046383
# word_freq_857                  -0.006717      -0.026748       -0.036835
# word_freq_data                 -0.008075      -0.031998       -0.034164
# word_freq_415                  -0.006729      -0.026960       -0.037315
# word_freq_85                   -0.006122      -0.049732       -0.054315
# word_freq_technology           -0.006515      -0.048844       -0.052819
# word_freq_1999                 -0.007761      -0.072599       -0.057465
# word_freq_parts                -0.002669       0.130812       -0.017918
# word_freq_pm                   -0.004602      -0.042044       -0.047619
# word_freq_direct               -0.007643      -0.021442       -0.029866
# word_freq_cs                   -0.005670      -0.047505       -0.029457
# word_freq_meeting              -0.008095       0.115041       -0.054812
# word_freq_original             -0.009268      -0.048879       -0.030616
# word_freq_project              -0.005933       0.015234       -0.028826
# word_freq_re                   -0.012957      -0.042336       -0.053637
# word_freq_edu                  -0.009181      -0.077986       -0.033046
# word_freq_table                -0.003348      -0.026900       -0.014343
# word_freq_conference           -0.001924      -0.032005       -0.031693
# char_freq_;                    -0.000591      -0.032759       -0.019119
# char_freq_(                    -0.012370      -0.046361       -0.008705
# char_freq_[                    -0.007148      -0.026390       -0.015133
# char_freq_!                    -0.003138       0.025509        0.065043
# char_freq_$                     0.010862       0.041582        0.105692
# char_freq_hash                 -0.000298       0.002016        0.019894
# capital_run_length_average      0.005260       0.052662       -0.010278
# capital_run_length_longest      0.022081       0.052290        0.090172
# capital_run_length_total        0.021369       0.002492        0.082089
#
#                             word_freq_remove  word_freq_internet  \
# word_freq_make                      0.007669           -0.003950
# word_freq_address                   0.003918           -0.016280
# word_freq_all                       0.036677            0.012003
# word_freq_3d                        0.019784            0.010268
# word_freq_our                       0.147336            0.029598
# word_freq_over                      0.061163            0.079561
# word_freq_remove                    1.000000            0.044545
# word_freq_internet                  0.044545            1.000000
# word_freq_order                     0.050786            0.105302
# word_freq_mail                      0.056809            0.083129
# word_freq_receive                   0.159578            0.128495
# word_freq_will                     -0.001461           -0.002973
# word_freq_people                    0.013295            0.026274
# word_freq_report                   -0.022723            0.012426
# word_freq_addresses                 0.042904            0.072782
# word_freq_free                      0.128436            0.051115
# word_freq_business                  0.187981            0.216422
# word_freq_email                     0.122011            0.037738
# word_freq_you                       0.111792            0.020641
# word_freq_credit                    0.046134            0.109163
# word_freq_your                      0.130794            0.156905
# word_freq_font                     -0.002093           -0.016192
# word_freq_000                       0.064795            0.089226
# word_freq_money                     0.030575            0.034127
# word_freq_hp                       -0.089494           -0.053038
# word_freq_hpl                      -0.080330           -0.041450
# word_freq_george                   -0.065893           -0.057189
# word_freq_650                      -0.066947           -0.049988
# word_freq_lab                      -0.048482           -0.037047
# word_freq_labs                     -0.058101           -0.043405
# word_freq_telnet                   -0.046280           -0.035816
# word_freq_857                      -0.040538           -0.034276
# word_freq_data                     -0.041372           -0.039220
# word_freq_415                      -0.040910           -0.034811
# word_freq_85                       -0.053202           -0.035174
# word_freq_technology               -0.053978           -0.033747
# word_freq_1999                     -0.052035           -0.017466
# word_freq_parts                    -0.014781           -0.012119
# word_freq_pm                       -0.046978           -0.030392
# word_freq_direct                   -0.022121           -0.005988
# word_freq_cs                       -0.033120           -0.003884
# word_freq_meeting                  -0.049664           -0.043626
# word_freq_original                 -0.049079           -0.004542
# word_freq_project                  -0.034461           -0.030134
# word_freq_re                       -0.050811           -0.002423
# word_freq_edu                      -0.056166           -0.037916
# word_freq_table                    -0.017512           -0.006397
# word_freq_conference               -0.031408           -0.021224
# char_freq_;                        -0.033089           -0.027432
# char_freq_(                        -0.051885           -0.032494
# char_freq_[                        -0.027653           -0.019548
# char_freq_!                         0.053706            0.031454
# char_freq_$                         0.070127            0.057910
# char_freq_hash                      0.046612           -0.008012
# capital_run_length_average          0.041565            0.011254
# capital_run_length_longest          0.059677            0.037575
# capital_run_length_total           -0.008344            0.040252
#
#                             word_freq_order  word_freq_mail  ...  \
# word_freq_make                     0.106263        0.041198  ...
# word_freq_address                 -0.003826        0.032962  ...
# word_freq_all                      0.093786        0.032075  ...
# word_freq_3d                      -0.002454       -0.004947  ...
# word_freq_our                      0.020823        0.034495  ...
# word_freq_over                     0.117438        0.013897  ...
# word_freq_remove                   0.050786        0.056809  ...
# word_freq_internet                 0.105302        0.083129  ...
# word_freq_order                    1.000000        0.130624  ...
# word_freq_mail                     0.130624        1.000000  ...
# word_freq_receive                  0.137760        0.125319  ...
# word_freq_will                     0.030344        0.071157  ...
# word_freq_people                   0.034738        0.045737  ...
# word_freq_report                   0.066840        0.017901  ...
# word_freq_addresses                0.238436        0.160543  ...
# word_freq_free                     0.008269        0.025601  ...
# word_freq_business                 0.158390        0.081363  ...
# word_freq_email                    0.098804        0.035977  ...
# word_freq_you                      0.039017        0.093509  ...
# word_freq_credit                   0.123217        0.030859  ...
# word_freq_your                     0.159112        0.098072  ...
# word_freq_font                    -0.019648        0.008200  ...
# word_freq_000                      0.126800        0.096809  ...
# word_freq_money                    0.099461        0.052129  ...
# word_freq_hp                      -0.069931       -0.033534  ...
# word_freq_hpl                     -0.049775       -0.013045  ...
# word_freq_george                  -0.064608       -0.067817  ...
# word_freq_650                     -0.056764        0.019356  ...
# word_freq_lab                     -0.044840       -0.026903  ...
# word_freq_labs                    -0.043643        0.008677  ...
# word_freq_telnet                  -0.040158       -0.024423  ...
# word_freq_857                     -0.033984       -0.015137  ...
# word_freq_data                    -0.014403       -0.035366  ...
# word_freq_415                     -0.033601       -0.014434  ...
# word_freq_85                      -0.041847       -0.020092  ...
# word_freq_technology              -0.056270       -0.016955  ...
# word_freq_1999                    -0.033244       -0.004944  ...
# word_freq_parts                   -0.002216       -0.017950  ...
# word_freq_pm                      -0.040844       -0.016091  ...
# word_freq_direct                  -0.009867        0.004163  ...
# word_freq_cs                      -0.035177       -0.025084  ...
# word_freq_meeting                 -0.048223       -0.054467  ...
# word_freq_original                -0.034190        0.023200  ...
# word_freq_project                 -0.035159       -0.026654  ...
# word_freq_re                      -0.075558       -0.032065  ...
# word_freq_edu                     -0.056817       -0.030326  ...
# word_freq_table                    0.007521       -0.015546  ...
# word_freq_conference              -0.026017       -0.016842  ...
# char_freq_;                       -0.014646        0.011945  ...
# char_freq_(                       -0.031003        0.003936  ...
# char_freq_[                        0.013601        0.007357  ...
# char_freq_!                        0.043639        0.036737  ...
# char_freq_$                        0.149365        0.075786  ...
# char_freq_hash                    -0.000522        0.044830  ...
# capital_run_length_average         0.111308        0.073677  ...
# capital_run_length_longest         0.189247        0.103308  ...
# capital_run_length_total           0.248724        0.087273  ...
#
#                             word_freq_conference  char_freq_;  char_freq_(  \
# word_freq_make                         -0.017755    -0.026505    -0.021196
# word_freq_address                      -0.015747    -0.007282    -0.049837
# word_freq_all                          -0.026344    -0.033213    -0.016495
# word_freq_3d                           -0.001924    -0.000591    -0.012370
# word_freq_our                          -0.032005    -0.032759    -0.046361
# word_freq_over                         -0.031693    -0.019119    -0.008705
# word_freq_remove                       -0.031408    -0.033089    -0.051885
# word_freq_internet                     -0.021224    -0.027432    -0.032494
# word_freq_order                        -0.026017    -0.014646    -0.031003
# word_freq_mail                         -0.016842     0.011945     0.003936
# word_freq_receive                      -0.022689    -0.032410    -0.055089
# word_freq_will                          0.032943    -0.027711    -0.030940
# word_freq_people                       -0.019746    -0.023445    -0.051151
# word_freq_report                       -0.016425    -0.019045    -0.005804
# word_freq_addresses                    -0.020818    -0.018277    -0.002551
# word_freq_free                         -0.028084    -0.026841    -0.046578
# word_freq_business                     -0.029947    -0.031542    -0.035897
# word_freq_email                        -0.017173    -0.039519    -0.035897
# word_freq_you                          -0.040015    -0.044314    -0.128882
# word_freq_credit                       -0.018198    -0.020851    -0.021431
# word_freq_your                         -0.050951    -0.058660    -0.085181
# word_freq_font                         -0.013168     0.416608    -0.046244
# word_freq_000                          -0.030155    -0.027362    -0.033174
# word_freq_money                        -0.019171    -0.019139    -0.033113
# word_freq_hp                           -0.002739     0.029181     0.136979
# word_freq_hpl                           0.032860     0.013558     0.144771
# word_freq_george                        0.007194    -0.022724    -0.028748
# word_freq_650                           0.004689    -0.025020     0.313835
# word_freq_lab                          -0.003303    -0.018502     0.158593
# word_freq_labs                         -0.005172    -0.019845     0.224192
# word_freq_telnet                       -0.013711    -0.016280     0.233392
# word_freq_857                          -0.011731    -0.008853     0.304679
# word_freq_data                          0.004533    -0.005691     0.028655
# word_freq_415                          -0.012065    -0.009290     0.303606
# word_freq_85                            0.002160    -0.021592     0.200713
# word_freq_technology                    0.010395    -0.018947     0.245454
# word_freq_1999                          0.048099     0.052138     0.107674
# word_freq_parts                         0.017660     0.007886    -0.010430
# word_freq_pm                            0.009546     0.034492     0.107928
# word_freq_direct                       -0.015802    -0.018693     0.268701
# word_freq_cs                           -0.001284     0.053034     0.017584
# word_freq_meeting                      -0.000529    -0.007817    -0.013082
# word_freq_original                     -0.006238     0.015385     0.060568
# word_freq_project                       0.000808    -0.007257    -0.003203
# word_freq_re                            0.005125    -0.024698     0.001413
# word_freq_edu                          -0.015719     0.015382     0.014763
# word_freq_table                        -0.006349     0.000995    -0.003085
# word_freq_conference                    1.000000    -0.002290    -0.012795
# char_freq_;                            -0.002290     1.000000     0.049124
# char_freq_(                            -0.012795     0.049124     1.000000
# char_freq_[                            -0.006310     0.009070     0.022316
# char_freq_!                            -0.026576     0.020539    -0.030354
# char_freq_$                            -0.030751     0.006392     0.044722
# char_freq_hash                         -0.008575     0.055057     0.023322
# capital_run_length_average             -0.008114     0.003443     0.034365
# capital_run_length_longest             -0.016894     0.040829     0.370963
# capital_run_length_total               -0.010033     0.055298     0.112209
#
#                             char_freq_[  char_freq_!  char_freq_$  \
# word_freq_make                -0.033301     0.058292     0.117419
# word_freq_address             -0.018527    -0.014461    -0.009605
# word_freq_all                 -0.033120     0.108140     0.087618
# word_freq_3d                  -0.007148    -0.003138     0.010862
# word_freq_our                 -0.026390     0.025509     0.041582
# word_freq_over                -0.015133     0.065043     0.105692
# word_freq_remove              -0.027653     0.053706     0.070127
# word_freq_internet            -0.019548     0.031454     0.057910
# word_freq_order                0.013601     0.043639     0.149365
# word_freq_mail                 0.007357     0.036737     0.075786
# word_freq_receive             -0.025183     0.024992     0.070227
# word_freq_will                -0.044966     0.013369     0.016723
# word_freq_people              -0.028283     0.040737     0.205905
# word_freq_report              -0.014349    -0.008499     0.080953
# word_freq_addresses           -0.003111     0.018607     0.123854
# word_freq_free                -0.029560     0.104261     0.049953
# word_freq_business            -0.036691     0.077049     0.098323
# word_freq_email               -0.017439     0.039350     0.063872
# word_freq_you                 -0.063826     0.153381     0.091470
# word_freq_credit              -0.012071     0.048350     0.034948
# word_freq_your                -0.045469     0.084017     0.141649
# word_freq_font                -0.001137    -0.004838    -0.011036
# word_freq_000                 -0.000467     0.070103     0.310971
# word_freq_money               -0.020798     0.051076     0.104691
# word_freq_hp                   0.039723    -0.090862    -0.086634
# word_freq_hpl                  0.064349    -0.078367    -0.081198
# word_freq_george              -0.017676    -0.067500    -0.068728
# word_freq_650                  0.031979    -0.063495    -0.061441
# word_freq_lab                  0.006575    -0.042330    -0.050231
# word_freq_labs                 0.004667    -0.061694    -0.065475
# word_freq_telnet               0.010718    -0.045273    -0.047475
# word_freq_857                  0.013805    -0.041529    -0.043484
# word_freq_data                 0.113105    -0.048493    -0.048101
# word_freq_415                  0.013687    -0.038626    -0.039844
# word_freq_85                   0.034435    -0.048822    -0.048947
# word_freq_technology           0.001017    -0.060379    -0.057933
# word_freq_1999                 0.073010    -0.054578    -0.063895
# word_freq_parts                0.001767    -0.015126    -0.012909
# word_freq_pm                   0.038474    -0.024846    -0.044513
# word_freq_direct               0.014065    -0.032509    -0.016724
# word_freq_cs                   0.034408    -0.025911    -0.036610
# word_freq_meeting              0.011091    -0.038094    -0.043653
# word_freq_original             0.115548    -0.049362    -0.054698
# word_freq_project             -0.010733    -0.033837    -0.036241
# word_freq_re                   0.008838     0.067569    -0.049367
# word_freq_edu                 -0.003168    -0.028845    -0.050109
# word_freq_table               -0.004592    -0.017679    -0.018549
# word_freq_conference          -0.006310    -0.026576    -0.030751
# char_freq_;                    0.009070     0.020539     0.006392
# char_freq_(                    0.022316    -0.030354     0.044722
# char_freq_[                    1.000000    -0.031769    -0.026400
# char_freq_!                   -0.031769     1.000000     0.142913
# char_freq_$                   -0.026400     0.142913     1.000000
# char_freq_hash                -0.006863     0.020924     0.012613
# capital_run_length_average    -0.008180     0.054308     0.079998
# capital_run_length_longest    -0.013994     0.077392     0.183144
# capital_run_length_total       0.006016     0.036321     0.201948
#
#                             char_freq_hash  capital_run_length_average  \
# word_freq_make                   -0.008844                    0.044491
# word_freq_address                 0.001946                    0.002083
# word_freq_all                    -0.003336                    0.097398
# word_freq_3d                     -0.000298                    0.005260
# word_freq_our                     0.002016                    0.052662
# word_freq_over                    0.019894                   -0.010278
# word_freq_remove                  0.046612                    0.041565
# word_freq_internet               -0.008012                    0.011254
# word_freq_order                  -0.000522                    0.111308
# word_freq_mail                    0.044830                    0.073677
# word_freq_receive                 0.001126                    0.029258
# word_freq_will                   -0.030445                   -0.010002
# word_freq_people                 -0.014195                   -0.013446
# word_freq_report                  0.006545                    0.003023
# word_freq_addresses              -0.005446                    0.017383
# word_freq_free                    0.035534                    0.015036
# word_freq_business               -0.000466                    0.038126
# word_freq_email                   0.020978                   -0.007979
# word_freq_you                    -0.002434                   -0.030592
# word_freq_credit                  0.007214                    0.067140
# word_freq_your                   -0.004355                    0.041066
# word_freq_font                    0.184428                    0.021497
# word_freq_000                     0.020140                    0.008372
# word_freq_money                   0.000703                    0.007681
# word_freq_hp                      0.058780                   -0.017285
# word_freq_hpl                    -0.020691                   -0.024234
# word_freq_george                 -0.020561                   -0.025504
# word_freq_650                    -0.011438                   -0.013757
# word_freq_lab                     0.002076                   -0.014936
# word_freq_labs                    0.082593                   -0.016599
# word_freq_telnet                  0.000225                   -0.010897
# word_freq_857                    -0.010735                   -0.010498
# word_freq_data                   -0.009928                   -0.015509
# word_freq_415                    -0.010635                   -0.002404
# word_freq_85                     -0.009650                   -0.013707
# word_freq_technology              0.006452                   -0.019185
# word_freq_1999                   -0.022637                   -0.014423
# word_freq_parts                  -0.003627                   -0.006012
# word_freq_pm                     -0.011326                   -0.014032
# word_freq_direct                 -0.010661                   -0.003945
# word_freq_cs                     -0.011755                   -0.008895
# word_freq_meeting                -0.003873                   -0.017899
# word_freq_original               -0.013925                   -0.017681
# word_freq_project                 0.001167                   -0.013157
# word_freq_re                     -0.023878                   -0.026979
# word_freq_edu                    -0.015040                   -0.017408
# word_freq_table                   0.000308                   -0.006465
# word_freq_conference             -0.008575                   -0.008114
# char_freq_;                       0.055057                    0.003443
# char_freq_(                       0.023322                    0.034365
# char_freq_[                      -0.006863                   -0.008180
# char_freq_!                       0.020924                    0.054308
# char_freq_$                       0.012613                    0.079998
# char_freq_hash                    1.000000                    0.013497
# capital_run_length_average        0.013497                    1.000000
# capital_run_length_longest        0.061657                    0.492638
# capital_run_length_total          0.042568                    0.162314
#
#                             capital_run_length_longest  \
# word_freq_make                                0.061382
# word_freq_address                             0.000271
# word_freq_all                                 0.107463
# word_freq_3d                                  0.022081
# word_freq_our                                 0.052290
# word_freq_over                                0.090172
# word_freq_remove                              0.059677
# word_freq_internet                            0.037575
# word_freq_order                               0.189247
# word_freq_mail                                0.103308
# word_freq_receive                             0.086791
# word_freq_will                                0.021774
# word_freq_people                              0.041962
# word_freq_report                              0.060993
# word_freq_addresses                           0.213992
# word_freq_free                                0.026528
# word_freq_business                            0.062672
# word_freq_email                               0.075122
# word_freq_you                                 0.006530
# word_freq_credit                              0.099463
# word_freq_your                                0.085321
# word_freq_font                                0.027775
# word_freq_000                                 0.123036
# word_freq_money                               0.044870
# word_freq_hp                                 -0.051206
# word_freq_hpl                                -0.051806
# word_freq_george                             -0.054400
# word_freq_650                                -0.038772
# word_freq_lab                                -0.034733
# word_freq_labs                               -0.039001
# word_freq_telnet                             -0.027449
# word_freq_857                                -0.027732
# word_freq_data                               -0.025919
# word_freq_415                                -0.024532
# word_freq_85                                 -0.030236
# word_freq_technology                         -0.038100
# word_freq_1999                               -0.033204
# word_freq_parts                              -0.009487
# word_freq_pm                                 -0.029229
# word_freq_direct                             -0.004835
# word_freq_cs                                 -0.023658
# word_freq_meeting                            -0.034585
# word_freq_original                           -0.017279
# word_freq_project                            -0.025918
# word_freq_re                                 -0.051858
# word_freq_edu                                -0.033365
# word_freq_table                              -0.010154
# word_freq_conference                         -0.016894
# char_freq_;                                   0.040829
# char_freq_(                                   0.370963
# char_freq_[                                  -0.013994
# char_freq_!                                   0.077392
# char_freq_$                                   0.183144
# char_freq_hash                                0.061657
# capital_run_length_average                    0.492638
# capital_run_length_longest                    1.000000
# capital_run_length_total                      0.475486
#
#                             capital_run_length_total
# word_freq_make                              0.089165
# word_freq_address                          -0.022680
# word_freq_all                               0.070114
# word_freq_3d                                0.021369
# word_freq_our                               0.002492
# word_freq_over                              0.082089
# word_freq_remove                           -0.008344
# word_freq_internet                          0.040252
# word_freq_order                             0.248724
# word_freq_mail                              0.087273
# word_freq_receive                           0.115055
# word_freq_will                              0.020076
# word_freq_people                            0.105150
# word_freq_report                            0.169257
# word_freq_addresses                         0.151626
# word_freq_free                              0.003007
# word_freq_business                          0.064261
# word_freq_email                             0.046364
# word_freq_you                              -0.007307
# word_freq_credit                            0.075751
# word_freq_your                              0.051797
# word_freq_font                              0.103954
# word_freq_000                               0.165977
# word_freq_money                             0.080993
# word_freq_hp                               -0.043267
# word_freq_hpl                              -0.059601
# word_freq_george                           -0.096548
# word_freq_650                              -0.067596
# word_freq_lab                              -0.056628
# word_freq_labs                             -0.064115
# word_freq_telnet                           -0.045923
# word_freq_857                              -0.046796
# word_freq_data                              0.006919
# word_freq_415                              -0.044529
# word_freq_85                               -0.045963
# word_freq_technology                       -0.045792
# word_freq_1999                             -0.003490
# word_freq_parts                            -0.013897
# word_freq_pm                               -0.049256
# word_freq_direct                           -0.028806
# word_freq_cs                               -0.026373
# word_freq_meeting                          -0.056511
# word_freq_original                         -0.036529
# word_freq_project                          -0.040661
# word_freq_re                               -0.095444
# word_freq_edu                              -0.046371
# word_freq_table                             0.005158
# word_freq_conference                       -0.010033
# char_freq_;                                 0.055298
# char_freq_(                                 0.112209
# char_freq_[                                 0.006016
# char_freq_!                                 0.036321
# char_freq_$                                 0.201948
# char_freq_hash                              0.042568
# capital_run_length_average                  0.162314
# capital_run_length_longest                  0.475486
# capital_run_length_total                    1.000000
#
# [57 rows x 57 columns]

# %%
from matplotlib import figure

#Checking the correlation
import seaborn as sns

fig = plt.figure.Figure(figsize =(12, 10))
features = df.columns
sns.heatmap(df[features].corr(), vmin=-1, vmax=1, center=0)
# Out:
# <Axes: >

# %%
X.columns
# Out:
# Index(['word_freq_make', 'word_freq_address', 'word_freq_all', 'word_freq_3d',
#        'word_freq_our', 'word_freq_over', 'word_freq_remove',
#        'word_freq_internet', 'word_freq_order', 'word_freq_mail',
#        'word_freq_receive', 'word_freq_will', 'word_freq_people',
#        'word_freq_report', 'word_freq_addresses', 'word_freq_free',
#        'word_freq_business', 'word_freq_email', 'word_freq_you',
#        'word_freq_credit', 'word_freq_your', 'word_freq_font', 'word_freq_000',
#        'word_freq_money', 'word_freq_hp', 'word_freq_hpl', 'word_freq_george',
#        'word_freq_650', 'word_freq_lab', 'word_freq_labs', 'word_freq_telnet',
#        'word_freq_857', 'word_freq_data', 'word_freq_415', 'word_freq_85',
#        'word_freq_technology', 'word_freq_1999', 'word_freq_parts',
#        'word_freq_pm', 'word_freq_direct', 'word_freq_cs', 'word_freq_meeting',
#        'word_freq_original', 'word_freq_project', 'word_freq_re',
#        'word_freq_edu', 'word_freq_table', 'word_freq_conference',
#        'char_freq_;', 'char_freq_(', 'char_freq__', 'char_freq_!',
#        'char_freq_$', 'char_freq_hash', 'capital_run_length_average',
#        'capital_run_length_longest', 'capital_run_length_total'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 

# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 
  
# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) 
                          for i in range(len(X.columns))] 
  
print(vif_data)
# Out:
#                        feature        VIF
# 0               word_freq_make   1.294396
# 1            word_freq_address   1.203471
# 2                word_freq_all   1.498145
# 3                 word_freq_3d   1.007237
# 4                word_freq_our   1.385788
# 5               word_freq_over   1.236195
# 6             word_freq_remove   1.267156
# 7           word_freq_internet   1.194788
# 8              word_freq_order   1.376715
# 9               word_freq_mail   1.339110
# 10           word_freq_receive   1.338766
# 11              word_freq_will   1.523263
# 12            word_freq_people   1.224777
# 13            word_freq_report   1.127036
# 14         word_freq_addresses   1.464250
# 15              word_freq_free   1.206453
# 16          word_freq_business   1.361504
# 17             word_freq_email   1.369509
# 18               word_freq_you   2.310682
# 19            word_freq_credit   1.136511
# 20              word_freq_your   2.115619
# 21              word_freq_font   1.275416
# 22               word_freq_000   1.518073
# 23             word_freq_money   1.217400
# 24                word_freq_hp   1.670626
# 25               word_freq_hpl   1.622013
# 26            word_freq_george   1.078208
# 27               word_freq_650   1.910191
# 28               word_freq_lab   1.863905
# 29              word_freq_labs   2.198434
# 30            word_freq_telnet   2.281864
# 31               word_freq_857  93.171452
# 32              word_freq_data   1.051646
# 33               word_freq_415  90.522493
# 34                word_freq_85   1.721004
# 35        word_freq_technology   2.362397
# 36              word_freq_1999   1.359925
# 37             word_freq_parts   1.065470
# 38                word_freq_pm   1.149574
# 39            word_freq_direct   3.394978
# 40                word_freq_cs   1.142508
# 41           word_freq_meeting   1.492186
# 42          word_freq_original   1.261744
# 43           word_freq_project   1.029792
# 44                word_freq_re   1.153646
# 45               word_freq_edu   1.152007
# 46             word_freq_table   1.014766
# 47        word_freq_conference   1.021510
# 48                 char_freq_;   1.226885
# 49                 char_freq_(   1.899331
# 50                 char_freq__   1.071723
# 51                 char_freq_!   1.245413
# 52                 char_freq_$   1.417370
# 53              char_freq_hash   1.091311
# 54  capital_run_length_average   1.496004
# 55  capital_run_length_longest   2.647793
# 56    capital_run_length_total   1.994436

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

pca = PCA().fit(X_train_std)

fig, ax = plt.subplots(figsize=(14,6))
x_values = range(1, pca.n_components_+1)
ax.bar(x_values, pca.explained_variance_ratio_, lw=2, label='Explained Variance')
ax.plot(x_values, np.cumsum(pca.explained_variance_ratio_), lw=2, label='Cumulative Explained Variance', color='red')
plt.plot([0,pca.n_components_+1],[0.90,0.90],'g--')
plt.plot([43,43],[0,1], 'g--')
ax.set_title('Explained variance of components')
ax.set_xlabel('Principal Component')
ax.set_ylabel('Explained Variance')
plt.grid()
plt.legend()
plt.show()

# %%
print('The shape of before get transformed training feature set:')
print(X_train_std.shape,"\n")
print('The shape of before get transformed training feature set:')
print(X_test_std.shape)
# Out:
# The shape of before get transformed training feature set:
# (4049, 57)
#
# The shape of before get transformed training feature set:
# (1013, 57)

# %%
#Applying PCA Transformations

pca = PCA(n_components=32)

X_train_std_pca = pca.fit_transform(X_train_std)
print('The shape of final transformed training feature set:')
print(X_train_std_pca.shape)
X_train_std_pca = pd.DataFrame(X_train_std_pca)

X_test_std_pca = pca.transform(X_test_std)
print('\nThe shape of final transformed testing feature set:')
print(X_test_std_pca.shape)
X_test_std_pca = pd.DataFrame(X_test_std_pca)
# Out:
# The shape of final transformed training feature set:
# (4049, 32)
#
# The shape of final transformed testing feature set:
# (1013, 32)

# %%
#Let us create first create a table to store the results of various models 

Evaluation_Results = pd.DataFrame(np.zeros((4,5)), 
                                  columns=['Accuracy', 'Precision','Recall','F1-score','AUC-ROC score'])

Evaluation_Results.index=['Support Vector Machine (SVM)', 'Cat-Boost',
                          'Light Gradient Boosting Machine (Light GBM)',
                         'Artificial Neural Network (ANN)']
Evaluation_Results
# Out:
#                                              Accuracy  Precision  Recall  \
# Support Vector Machine (SVM)                      0.0        0.0     0.0
# Cat-Boost                                         0.0        0.0     0.0
# Light Gradient Boosting Machine (Light GBM)       0.0        0.0     0.0
# Artificial Neural Network (ANN)                   0.0        0.0     0.0
#
#                                              F1-score  AUC-ROC score
# Support Vector Machine (SVM)                      0.0            0.0
# Cat-Boost                                         0.0            0.0
# Light Gradient Boosting Machine (Light GBM)       0.0            0.0
# Artificial Neural Network (ANN)                   0.0            0.0

# %%
#Let us define functions to summarise the Prediction's scores .
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,confusion_matrix,classification_report
import scikitplot as skplt

#Classification Summary Function
def Classification_Summary(y_true,pred,pred_prob,i):
    Evaluation_Results.iloc[i]['Accuracy']=round(accuracy_score(y_test, pred),3)*100   
    Evaluation_Results.iloc[i]['Precision']=round(precision_score(y_test, pred, average='weighted'),3)*100 #
    Evaluation_Results.iloc[i]['Recall']=round(recall_score(y_test, pred, average='weighted'),3)*100 #
    Evaluation_Results.iloc[i]['F1-score']=round(f1_score(y_test, pred, average='weighted'),3)*100 #
    Evaluation_Results.iloc[i]['AUC-ROC score']=round(roc_auc_score(y_test, pred_prob[:,1], multi_class='ovr'),3)*100 #[:, 1]
    print('{}{}\033[1m Evaluating {} \033[0m{}{}\n'.format('<'*3,'-'*25,Evaluation_Results.index[i], '-'*35,'>'*25))
    print('Accuracy = {}%'.format(round(accuracy_score(y_test, pred),3)*100))
    print('F1 Score = {}%'.format(round(f1_score(y_test, pred, average='weighted'),3)*100)) #
    print('\n \033[1mConfusiton Matrix:\033[0m\n',confusion_matrix(y_test, pred))
    print('\n\033[1mClassification Report:\033[0m\n',classification_report(y_test, pred))
    
    skplt.metrics.plot_roc_curve(y_test, pred_prob)
    plt.show()

# %% [markdown]
# # SVM

# %%
# Building Support Vector Machine Classifier
from sklearn import svm
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import RandomizedSearchCV

SVM_model = svm.SVC(probability=True).fit(X_train_std, y_train)

svm_param = {"C": [.01, .1, 1, 5, 10, 100],             
             "gamma": [.01, .1, 1, 5, 10, 100],
             "kernel": ["rbf"],
             "random_state": [1]}

cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

RCV = RandomizedSearchCV(SVM_model, svm_param, n_iter=50, scoring='roc_auc', n_jobs=-1, cv=5, random_state=1)

SVM = RCV.fit(X_train_std, y_train).best_estimator_
pred = SVM.predict(X_test_std)
pred_prob = SVM.predict_proba(X_test_std)

# %%
Classification_Summary(y_test,pred,pred_prob,0)
# Out:
# <<<------------------------- Evaluating Support Vector Machine (SVM) ----------------------------------->>>>>>>>>>>>>>>>>>>>>>>>>
#
# Accuracy = 94.1%
# F1 Score = 94.1%
#
#  Confusiton Matrix:
#  [[490  23]
#  [ 37 463]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       513
#            1       0.95      0.93      0.94       500
#
#     accuracy                           0.94      1013
#    macro avg       0.94      0.94      0.94      1013
# weighted avg       0.94      0.94      0.94      1013

# %% [markdown]
# # LightGBM

# %%
# Building Support Vector Machine Classifier
import lightgbm as lgb

lgb_model = lgb.LGBMClassifier().fit(X_train_std, y_train)

lgb_param = {'bagging_fraction': (0.5, 0.8),
            'bagging_frequency': (5, 8),
            'feature_fraction': (0.5, 0.8),
            'max_depth': (10, 13),
            'min_data_in_leaf': (90, 120),
            'num_leaves': (1200, 1550)}

cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

RCV = RandomizedSearchCV(lgb_model, lgb_param, n_iter=50, scoring='roc_auc', n_jobs=-1, cv=5, random_state=1)

LGB = RCV.fit(X_train_std, y_train).best_estimator_
pred = LGB.predict(X_test_std)
pred_prob = LGB.predict_proba(X_test_std)
# Out:
# [LightGBM] [Info] Number of positive: 2031, number of negative: 2018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001710 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9780
# [LightGBM] [Info] Number of data points in the train set: 4049, number of used features: 57
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501605 -> initscore=0.006421
# [LightGBM] [Info] Start training from score 0.006421
# [LightGBM] [Warning] Unknown parameter: bagging_frequency
# [LightGBM] [Warning] min_data_in_leaf is set=90, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=90
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] Unknown parameter: bagging_frequency
# [LightGBM] [Warning] min_data_in_leaf is set=90, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=90
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Info] Number of positive: 2031, number of negative: 2018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001617 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9710
# [LightGBM] [Info] Number of data points in the train set: 4049, number of used features: 54
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501605 -> initscore=0.006421
# [LightGBM] [Info] Start training from score 0.006421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: bagging_frequency
# [LightGBM] [Warning] min_data_in_leaf is set=90, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=90
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] Unknown parameter: bagging_frequency
# [LightGBM] [Warning] min_data_in_leaf is set=90, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=90
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8

# %%
Classification_Summary(y_test,pred,pred_prob,2)
# Out:
# <<<------------------------- Evaluating Light Gradient Boosting Machine (Light GBM) ----------------------------------->>>>>>>>>>>>>>>>>>>>>>>>>
#
# Accuracy = 96.0%
# F1 Score = 96.0%
#
#  Confusiton Matrix:
#  [[492  21]
#  [ 20 480]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       513
#            1       0.96      0.96      0.96       500
#
#     accuracy                           0.96      1013
#    macro avg       0.96      0.96      0.96      1013
# weighted avg       0.96      0.96      0.96      1013

# %% [markdown]
# #Eğitim ve test veri kümelerini ayırırken ;
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0,stratify=y) #y-hedef değişken
# ....
# -----------
# #Çapraz-doğrulama skorunu hesaplarken ;
# from sklearn.model_selection import StratifiedKFold, cross_val_score
# skf = StratifiedKFold(n_splits=10)
# score = cross_val_score(classifier, X, y, cv=cv=skf.split(X,y))
# ....
# -----------
# #RandomizedSearchCV /GridSearchCV uygularken ;
# cv = StratifiedShuffleSplit(n_splits=5, random_state=1)
# classifier = RandomizedSearchCV(classifier,parameter=parameters,
# cv=cv)
